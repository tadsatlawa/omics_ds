# %% [markdown]
# # Genomika część 2 (BaseSpace)

# %% [markdown]
# ## Zadanie 1
# Przeprowadź analizę z wykorzystaniem potoku przetwarzania danych DRAGEN Germline
# Pipeline: Wybierz ze strony startowej „Sequence Hub US”, następnie w zakładce „Projects”
# stwórz nowy projekt, w którym następnie dodaj ściągnięte pliki fastq. Nastepnie w zakładce
# „Apps” szukamy programu DRAGEN Germline Pipeline (czerowna ikonka) i wykonaj analizę.
# (Jako „Reference” wybieramy „Human (Ensembl GRCh37)”, „Library prep kit” wybieramy
# dowolny).

# %% [markdown]
# ### Po skończonej analizie w zakładce „Reports” danej analizy podaj całkowita liczbę odczytów („Total input reads”)

# %% [markdown]
# Jest 3444056 readów:
#
# ![image.png](attachment:de99f8af-a757-4fce-ad1c-0cda4ce073f3.png)

# %% [markdown]
# ### Podaj liczbę odczytów z jakością MAPQ powyżej 40.

# %% [markdown]
# 3207798 readów: ![image.png](attachment:beca9821-1a24-415e-a0b9-88735aeeb9e3.png)

# %% [markdown]
# ## Zadanie 2
# Przeprowadź wykrywanie wariantów: Wybierz ze strony startowej „Variant Interpreter US”,
# następnie w prawym górnym rogu kliknij na Import: Import From BaseSpace Sequence Hub i
# wybierz plik vcf utworzony w poprzedniej analizie. Po zakończeniu analizy należy kliknąć w
# daną próbkę i w prawym górnym rogu kliknąć „Add Subject” i dowolnie wypełnić wymagane
# pola („Sample Class” wybrać „Germline”, jako płeć proszę wybrać „Male”)

# %% [markdown]
# ### Proszę podać pozycję chromosomową i rodzaj zmiany dwóch wariantów zaklasyfikowanych jako patogenne

# %% [markdown]
# 1. `chr8:61761624`, `G->A` typu stop gained
# 2.  `chrMT:14831`, `G->A`, typu missense
#
# ![image.png](attachment:902e40d3-d4db-4709-9a22-46095192ef75.png)

# %% [markdown]
# ### Ile jest wariantów wykrytych na chromosomie 1? (opcja „Apply Variant Filters”)

# %% [markdown]
# 6917
#
# ![image.png](attachment:4234095d-7f7d-448a-b2fc-082d01ec4940.png)
